# %% [markdown]
# # 🏡 Rigenerazione Portafoglio Immobili - Antonio Giancani
#
# Questo notebook ti permette di elaborare i tuoi 146 immobili dal foglio Google Sheets, estrarre i fotogrammi dei video di YouTube e pubblicare tutto su WordPress ed all'interno della tua nuova Homepage di personal branding.
#
# ## 🔑 IMPORTANTE: Configura i Segreti prima di iniziare
# Prima di avviare il codice, clicca sull'icona della **chiave (🔑)** nella barra laterale di sinistra di Colab ed aggiungi tre segreti:
# 1. **Nome**: `WP_TOKEN` | **Valore**: *[IL_TUO_WP_TOKEN_QUI]*
# 2. **Nome**: `GROQ_API_KEY` | **Valore**: *[LA_TUA_GROQ_API_KEY_QUI]*
# 3. **Nome**: `GOOGLE_APPLICATION_CREDENTIALS` | **Valore**: *(incolla qui il contenuto JSON del tuo file delle credenziali)*
#
# Assicurati di **attivare l'interruttore 'Accesso Notebook' (Notebook access)** per tutti e tre i segreti.

# %%
# Cella 1: Clona il repository ed installa i requisiti
# !git clone https://github.com/Tonyhood2345/TELEGRAMGRUPPOVIDEOAgenziaBOT.git
# %cd TELEGRAMGRUPPOVIDEOAgenziaBOT

# Installa le librerie necessarie
# !pip install -U yt-dlp requests gspread google-auth

# %%
# Cella 2: Carica le credenziali ed imposta le variabili d'ambiente
import os
from google.colab import userdata

os.environ['WP_TOKEN'] = userdata.get('WP_TOKEN')
os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = userdata.get('GOOGLE_APPLICATION_CREDENTIALS')
os.environ['WP_URL'] = 'https://www.immobiliaregiancani.it/wp-json/easy-mcp-ai/v1/mcp'

print("✅ Variabili d'ambiente caricate ed impostate con successo per Antonio Giancani!")

# %%
# Cella 3: Esegui la rigenerazione degli immobili
# !python rigenera_tutti_gli_immobili.py
